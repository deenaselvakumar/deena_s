# %% [markdown]
# <a href="https://colab.research.google.com/github/deenaselvakumar/deena_s/blob/main/edge_dedection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
image = cv2.imread('/content/3.jpg', cv2.IMREAD_GRAYSCALE)  # Load the image in grayscale

# Apply Sobel filter for edge detection
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)  # Sobel filter in x direction
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)  # Sobel filter in y direction

# Compute the magnitude of the gradients
magnitude = cv2.magnitude(sobel_x, sobel_y)

# Display the results
plt.figure(figsize=(10, 10))
plt.subplot(1, 3, 1), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(1, 3, 2), plt.imshow(sobel_x, cmap='gray'), plt.title('Sobel X')
plt.subplot(1, 3, 3), plt.imshow(sobel_y, cmap='gray'), plt.title('Sobel Y')

# Show magnitude of the gradient
plt.figure(figsize=(5, 5))
plt.imshow(magnitude, cmap='gray')
plt.title('Edge Magnitude')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
image = cv2.imread('/content/3.jpg', cv2.IMREAD_GRAYSCALE)  # Load the image in grayscale

# Define Prewitt kernels
prewitt_kernel_x = np.array([[-1, 0, 1],
                             [-1, 0, 1],
                             [-1, 0, 1]])

prewitt_kernel_y = np.array([[-1, -1, -1],
                             [0, 0, 0],
                             [1, 1, 1]])

# Apply Prewitt filter for edge detection
prewitt_x = cv2.filter2D(image, cv2.CV_64F, prewitt_kernel_x)  # Prewitt filter in x direction
prewitt_y = cv2.filter2D(image, cv2.CV_64F, prewitt_kernel_y)  # Prewitt filter in y direction

# Compute the magnitude of the gradients
magnitude = cv2.magnitude(prewitt_x, prewitt_y)

# Display the results
plt.figure(figsize=(10, 10))
plt.subplot(1, 3, 1), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(1, 3, 2), plt.imshow(prewitt_x, cmap='gray'), plt.title('Prewitt X')
plt.subplot(1, 3, 3), plt.imshow(prewitt_y, cmap='gray'), plt.title('Prewitt Y')

# Show magnitude of the gradient
plt.figure(figsize=(5, 5))
plt.imshow(magnitude, cmap='gray')
plt.title('Edge Magnitude')
plt.show()
